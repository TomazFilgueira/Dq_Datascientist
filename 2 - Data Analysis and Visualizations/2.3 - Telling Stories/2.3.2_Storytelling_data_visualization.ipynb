# %%
import pandas as pd
import matplotlib.pyplot as plt

death_toll = pd.read_csv('covid_avg_deaths.csv')

fig, axes = plt.subplots(nrows=4, ncols=1, figsize=(6,8))
axes[0].plot(death_toll['Month'],death_toll['New_deaths'])
axes[1].plot(death_toll['Month'],death_toll['New_deaths'])
axes[2].plot(death_toll['Month'],death_toll['New_deaths'])
axes[3].plot(death_toll['Month'],death_toll['New_deaths'])
plt.show()

# %% [markdown]
# Using a for loop

# %%
fig, axes = plt.subplots(nrows=4, ncols=1, figsize=(6,8))
for ax in axes:
    ax.plot(death_toll['Month'], death_toll['New_deaths'])
plt.show()

# %% [markdown]
# We can also use the loop to apply a change to all Axes objects. Below, for instance, we **remove** the y- and x-tick labels for all plots:

# %%
fig, axes = plt.subplots(nrows=4, ncols=1, figsize=(6,8))
for ax in axes:
    ax.plot(death_toll['Month'], death_toll['New_deaths'])
    ax.set_yticklabels([])
    ax.set_xticklabels([])
plt.show()

# %% [markdown]
# In the spirit of maximizing the data-ink ratio, let's also remove the ticks and the **spines** (the x- and y-axes).

# %%
import pandas as pd
import matplotlib.pyplot as plt

death_toll = pd.read_csv('covid_avg_deaths.csv')
fig, axes = plt.subplots(nrows=4, ncols=1, figsize=(6,8))

for ax in axes:
    ax.plot(death_toll['Month'], death_toll['New_deaths'])
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    ax.tick_params(left=False,bottom=False)
    
    ax.spines[['left','bottom','top','right']].set_visible(False)
    
plt.show()

# %% [markdown]
# # 4 - MOdifying the line plots
#
# The storytelling data visualization we first showed emphasizes four periods:
#
# * January–March
# * March–June
# * June–October
# * October–December
#
# ![image.png](attachment:image.png)
#
# To highlight these four periods, we begin by coloring all plots in a shade of red. Then, we increase their transparency by using the `alpha` parameter.

# %%
death_toll = pd.read_csv('covid_avg_deaths.csv')
fig, axes = plt.subplots(nrows=4, ncols=1, figsize=(6,8))

for ax in axes:
    ax.plot(death_toll['Month'], death_toll['New_deaths'],color='#af0b1e', alpha=0.1)
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    ax.tick_params(left=False,bottom=False)
    ax.spines[['left','bottom','top','right']].set_visible(False)
    
    

#Now, we draw separate line plots on top of the current ones.
# begin by drawing the first one
# we use the same color and increase the line width using the linewidth parameter.
axes[0].plot(death_toll['Month'][:3], death_toll['New_deaths'][:3],
         color='#af0b1e', linewidth=2.5)

#Highlight subplot 2
axes[1].plot(death_toll['Month'][2:6], death_toll['New_deaths'][2:6],
         color='#af0b1e', linewidth=2.5)

#Highlight the June–October period on the third plot
axes[2].plot(death_toll['Month'][5:10], death_toll['New_deaths'][5:10],
         color='#af0b1e', linewidth=2.5)

#Highlight the October–December period on the fourth plot.
axes[3].plot(death_toll['Month'][9:12], death_toll['New_deaths'][9:12],
         color='#af0b1e', linewidth=2.5)

plt.show()

# %% [markdown]
# # 5 Adding structural Elements
#
# First, we're going to show the quantities by adding three labels on the first plot — we do this using the `Axis.text()` method. We arrived at the exact x- and y-coordinates you see below through a process of trial and error.
#
# The three labels give the audience a sense of the magnitude and the range of the quantities. We only want to show people a trend, so these three labels are enough. The other three plots are identical, so we don't need to add more ink.

# %%
import pandas as pd
import matplotlib.pyplot as plt

death_toll = pd.read_csv('covid_avg_deaths.csv')

fig, axes = plt.subplots(nrows=4, ncols=1, figsize=(6,8))

for ax in axes:
    ax.plot(death_toll['Month'], death_toll['New_deaths'],
            color='#af0b1e', alpha=0.1)
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    ax.tick_params(bottom=False, left=False) 
    for location in ['left', 'right', 'top', 'bottom']:
        ax.spines[location].set_visible(False)

axes[0].plot(death_toll['Month'][:3], death_toll['New_deaths'][:3],
         color='#af0b1e', linewidth=2.5)
axes[1].plot(death_toll['Month'][2:6], death_toll['New_deaths'][2:6],
         color='#af0b1e', linewidth=2.5)
axes[2].plot(death_toll['Month'][5:10], death_toll['New_deaths'][5:10],
         color='#af0b1e', linewidth=2.5)
axes[3].plot(death_toll['Month'][9:12], death_toll['New_deaths'][9:12],
         color='#af0b1e', linewidth=2.5)

axes[0].text(0.5, -80, '0', alpha=0.5)
axes[0].text(3.5, 2000, '1,844', alpha=0.5)
axes[0].text(11.5, 2400, '2,247', alpha=0.5)

axes[0].text(1.1, -300, 'Jan - Mar', color='#af0b1e',
         weight='bold', rotation=3)
axes[0].text(0.5, -80, '0', alpha=0.5)
axes[0].text(3.5, 2000, '1,844', alpha=0.5)
axes[0].text(11.5, 2400, '2,247', alpha=0.5)
plt.show()

# %% [markdown]
# Below, we add the 'Jan-Mar' label using `Axes.text().` Specifically, notice the rotation parameter we use to slightly rotate the text.

# %%
import pandas as pd
import matplotlib.pyplot as plt

death_toll = pd.read_csv('covid_avg_deaths.csv')

fig, axes = plt.subplots(nrows=4, ncols=1, figsize=(6,8))

for ax in axes:
    ax.plot(death_toll['Month'], death_toll['New_deaths'],
            color='#af0b1e', alpha=0.1)
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    ax.tick_params(bottom=False, left=False) 
    for location in ['left', 'right', 'top', 'bottom']:
        ax.spines[location].set_visible(False)

axes[0].plot(death_toll['Month'][:3], death_toll['New_deaths'][:3],
         color='#af0b1e', linewidth=2.5)
axes[1].plot(death_toll['Month'][2:6], death_toll['New_deaths'][2:6],
         color='#af0b1e', linewidth=2.5)
axes[2].plot(death_toll['Month'][5:10], death_toll['New_deaths'][5:10],
         color='#af0b1e', linewidth=2.5)
axes[3].plot(death_toll['Month'][9:12], death_toll['New_deaths'][9:12],
         color='#af0b1e', linewidth=2.5)

axes[0].text(0.5, -80, '0', alpha=0.5)
axes[0].text(3.5, 2000, '1,844', alpha=0.5)
axes[0].text(11.5, 2400, '2,247', alpha=0.5)

axes[0].text(1.1, -300, 'Jan - Mar', color='#af0b1e',
         weight='bold', rotation=3)
axes[0].text(0.5, -80, '0', alpha=0.5)
axes[0].text(3.5, 2000, '1,844', alpha=0.5)
axes[0].text(11.5, 2400, '2,247', alpha=0.5)

# Assume the rest of the code is written
axes[0].text(1.1, -300, 'Jan - Mar', color='#af0b1e',
         weight='bold', rotation=3)
plt.show()

# %% [markdown]
# Let's now add labels for the other three periods. We've already added the code for the first period and for the quantity labels.

# %%
import pandas as pd
import matplotlib.pyplot as plt

death_toll = pd.read_csv('covid_avg_deaths.csv')

fig, axes = plt.subplots(nrows=4, ncols=1, figsize=(6,8))

for ax in axes:
    ax.plot(death_toll['Month'], death_toll['New_deaths'],
            color='#af0b1e', alpha=0.1)
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    ax.tick_params(bottom=False, left=False) 
    for location in ['left', 'right', 'top', 'bottom']:
        ax.spines[location].set_visible(False)

axes[0].plot(death_toll['Month'][:3], death_toll['New_deaths'][:3],
         color='#af0b1e', linewidth=2.5)
axes[1].plot(death_toll['Month'][2:6], death_toll['New_deaths'][2:6],
         color='#af0b1e', linewidth=2.5)
axes[2].plot(death_toll['Month'][5:10], death_toll['New_deaths'][5:10],
         color='#af0b1e', linewidth=2.5)
axes[3].plot(death_toll['Month'][9:12], death_toll['New_deaths'][9:12],
         color='#af0b1e', linewidth=2.5)

axes[0].text(0.5, -80, '0', alpha=0.5)
axes[0].text(3.5, 2000, '1,844', alpha=0.5)
axes[0].text(11.5, 2400, '2,247', alpha=0.5)

axes[0].text(1.1, -300, 'Jan - Mar', color='#af0b1e',
         weight='bold', rotation=3)

axes[1].text(3.7, 800, 'Mar - Jun', color='#af0b1e',
         weight='bold')

axes[2].text(7.1, 500, 'Jun - Oct', color='#af0b1e',
         weight='bold')

axes[3].text(10.5, 600, 'Oct - Dec', color='#af0b1e',
         weight='bold', rotation=45)

plt.show()

# %% [markdown]
# # 6 title and subtitle
#
# Add the title The virus kills 851 people each day to the first Axes object (data source: World Health Organization). The text must have the following properties:
#
# * the x-coordinate is 0.5.
# * The y-coordinate is 3500.
# * The font size is 14.
# * It is bolded.

# %%
import pandas as pd
import matplotlib.pyplot as plt

death_toll = pd.read_csv('covid_avg_deaths.csv')

fig, axes = plt.subplots(nrows=4, ncols=1, figsize=(6,8))

for ax in axes:
    ax.plot(death_toll['Month'], death_toll['New_deaths'],
            color='#af0b1e', alpha=0.1)
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    ax.tick_params(bottom=False, left=False) 
    for location in ['left', 'right', 'top', 'bottom']:
        ax.spines[location].set_visible(False)
        
axes[0].plot(death_toll['Month'][:3], death_toll['New_deaths'][:3],
         color='#af0b1e', linewidth=2.5)
axes[1].plot(death_toll['Month'][2:6], death_toll['New_deaths'][2:6],
         color='#af0b1e', linewidth=2.5)
axes[2].plot(death_toll['Month'][5:10], death_toll['New_deaths'][5:10],
         color='#af0b1e', linewidth=2.5)
axes[3].plot(death_toll['Month'][9:12], death_toll['New_deaths'][9:12],
         color='#af0b1e', linewidth=2.5)

axes[0].text(0.5, -80, '0', alpha=0.5)
axes[0].text(3.5, 2000, '1,844', alpha=0.5)
axes[0].text(11.5, 2400, '2,247', alpha=0.5)

axes[0].text(1.1, -300, 'Jan - Mar', color='#af0b1e',
         weight='bold', rotation=3)
axes[1].text(3.7, 800, 'Mar - Jun', color='#af0b1e', weight='bold')
axes[2].text(7.1, 500, 'Jun - Oct', color='#af0b1e', weight='bold')
axes[3].text(10.5, 600, 'Oct - Dec', color='#af0b1e', weight='bold',
        rotation=45)

#title
axes[0].text(0.5, 3500, 'The virus kills 851 people each day',weight='bold', size=14)

#subtitle
axes[0].text(0.5, 3150, 'Average number of daily deaths per month in the US', size=12)

plt.show()

# %% [markdown]
# # 7 Adding progress bar
#
# The progress bars follow the change in the total number of cumulative deaths over the four highlighted periods. They represent a detailed breakdown of the death toll in the United States.
#
# We don't have a Matplotlib function specifically built for creating progress bars. Our approach, however, is to do the following:
#
# 1. Determine the basic parts of a progress bar.
# 1. Use Matplotlib to create those parts.
#
# A progress bar is made of **two rectangles**. The rectangles are different colors, and the one with a **darker shade** is put on top of the other — this creates a visual sense of progress.
#
# To create a rectangle in Matplotlib, we can draw a thick horizontal line. To draw a horizontal line, we can use the `Axes.axhline()` method. The y parameter specifies the y-coordinate of the horizontal line.

# %%
import pandas as pd
import matplotlib.pyplot as plt

death_toll = pd.read_csv('covid_avg_deaths.csv')

fig, axes = plt.subplots(nrows=4, ncols=1, figsize=(6,8))

for ax in axes:
    ax.plot(death_toll['Month'], death_toll['New_deaths'],
            color='#af0b1e', alpha=0.1)
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    ax.tick_params(bottom=False, left=False) 
    for location in ['left', 'right', 'top', 'bottom']:
        ax.spines[location].set_visible(False)
        
axes[0].plot(death_toll['Month'][:3], death_toll['New_deaths'][:3],
         color='#af0b1e', linewidth=2.5)
axes[1].plot(death_toll['Month'][2:6], death_toll['New_deaths'][2:6],
         color='#af0b1e', linewidth=2.5)
axes[2].plot(death_toll['Month'][5:10], death_toll['New_deaths'][5:10],
         color='#af0b1e', linewidth=2.5)
axes[3].plot(death_toll['Month'][9:12], death_toll['New_deaths'][9:12],
         color='#af0b1e', linewidth=2.5)

axes[0].text(0.5, -80, '0', alpha=0.5)
axes[0].text(3.5, 2000, '1,844', alpha=0.5)
axes[0].text(11.5, 2400, '2,247', alpha=0.5)

axes[0].text(1.1, -300, 'Jan - Mar', color='#af0b1e',
         weight='bold', rotation=3)
axes[1].text(3.7, 800, 'Mar - Jun', color='#af0b1e', weight='bold')
axes[2].text(7.1, 500, 'Jun - Oct', color='#af0b1e', weight='bold')
axes[3].text(10.5, 600, 'Oct - Dec', color='#af0b1e', weight='bold',
        rotation=45)

axes[0].text(0.5, 3500, 'The virus kills 851 people each day',
         size=14, weight='bold')
axes[0].text(0.5, 3150, 'Average number of daily deaths per month in the US',
         size=12) 

# Assume the rest of the code is written
axes[0].axhline(y=1600)

# %% [markdown]
# Now that we have drawn a horizontal line, we need to do the following:
#
# 1. Make the line shorter — we control the line's length using `xmin` and `xmax` parameters.
# 1. Increase the line's width to make it look like a rectangle — we use the `linewidth` parameter.
# 1. Change the color to '`#af0b1e`' and increase its transparency — we use the `color` and `alpha` parameters.

# %%
import pandas as pd
import matplotlib.pyplot as plt

death_toll = pd.read_csv('covid_avg_deaths.csv')

fig, axes = plt.subplots(nrows=4, ncols=1, figsize=(6,8))

for ax in axes:
    ax.plot(death_toll['Month'], death_toll['New_deaths'],
            color='#af0b1e', alpha=0.1)
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    ax.tick_params(bottom=False, left=False) 
    for location in ['left', 'right', 'top', 'bottom']:
        ax.spines[location].set_visible(False)
        
axes[0].plot(death_toll['Month'][:3], death_toll['New_deaths'][:3],
         color='#af0b1e', linewidth=2.5)
axes[1].plot(death_toll['Month'][2:6], death_toll['New_deaths'][2:6],
         color='#af0b1e', linewidth=2.5)
axes[2].plot(death_toll['Month'][5:10], death_toll['New_deaths'][5:10],
         color='#af0b1e', linewidth=2.5)
axes[3].plot(death_toll['Month'][9:12], death_toll['New_deaths'][9:12],
         color='#af0b1e', linewidth=2.5)

axes[0].text(0.5, -80, '0', alpha=0.5)
axes[0].text(3.5, 2000, '1,844', alpha=0.5)
axes[0].text(11.5, 2400, '2,247', alpha=0.5)

axes[0].text(1.1, -300, 'Jan - Mar', color='#af0b1e',
         weight='bold', rotation=3)
axes[1].text(3.7, 800, 'Mar - Jun', color='#af0b1e', weight='bold')
axes[2].text(7.1, 500, 'Jun - Oct', color='#af0b1e', weight='bold')
axes[3].text(10.5, 600, 'Oct - Dec', color='#af0b1e', weight='bold',
        rotation=45)

axes[0].text(0.5, 3500, 'The virus kills 851 people each day',
         size=14, weight='bold')
axes[0].text(0.5, 3150, 'Average number of daily deaths per month in the US',
         size=12) 

# Assume the rest of the code is written
axes[0].axhline(y=1600, xmin=0.5, xmax=0.8,
           linewidth=6, color='#af0b1e', alpha=0.1)

# %% [markdown]
# Now let's draw this line on all four plots.

# %%
import pandas as pd
import matplotlib.pyplot as plt

death_toll = pd.read_csv('covid_avg_deaths.csv')

fig, axes = plt.subplots(nrows=4, ncols=1, figsize=(6,8))

for ax in axes:
    ax.plot(death_toll['Month'], death_toll['New_deaths'],
            color='#af0b1e', alpha=0.1)
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    ax.tick_params(bottom=False, left=False) 
    for location in ['left', 'right', 'top', 'bottom']:
        ax.spines[location].set_visible(False)
        
axes[0].plot(death_toll['Month'][:3], death_toll['New_deaths'][:3],
         color='#af0b1e', linewidth=2.5)
axes[1].plot(death_toll['Month'][2:6], death_toll['New_deaths'][2:6],
         color='#af0b1e', linewidth=2.5)
axes[2].plot(death_toll['Month'][5:10], death_toll['New_deaths'][5:10],
         color='#af0b1e', linewidth=2.5)
axes[3].plot(death_toll['Month'][9:12], death_toll['New_deaths'][9:12],
         color='#af0b1e', linewidth=2.5)

axes[0].text(0.5, -80, '0', alpha=0.5)
axes[0].text(3.5, 2000, '1,844', alpha=0.5)
axes[0].text(11.5, 2400, '2,247', alpha=0.5)

axes[0].text(1.1, -300, 'Jan - Mar', color='#af0b1e',
         weight='bold', rotation=3)
axes[1].text(3.7, 800, 'Mar - Jun', color='#af0b1e', weight='bold')
axes[2].text(7.1, 500, 'Jun - Oct', color='#af0b1e', weight='bold')
axes[3].text(10.5, 600, 'Oct - Dec', color='#af0b1e', weight='bold',
        rotation=45)

axes[0].text(0.5, 3500, 'The virus kills 851 people each day',
         size=14, weight='bold')
axes[0].text(0.5, 3150, 'Average number of daily deaths per month in the US',
         size=12) 

#Four plots
axes[0].axhline(y=1600, xmin=0.5, xmax=0.8,
           linewidth=6, color='#af0b1e', alpha=0.1)

axes[1].axhline(y=1600, xmin=0.5, xmax=0.8,
           linewidth=6, color='#af0b1e', alpha=0.1)

axes[2].axhline(y=1600, xmin=0.5, xmax=0.8,
           linewidth=6, color='#af0b1e', alpha=0.1)

axes[3].axhline(y=1600, xmin=0.5, xmax=0.8,
           linewidth=6, color='#af0b1e', alpha=0.1)

plt.show()

# %% [markdown]
# # Completing the progress Bar

# %%
import pandas as pd
import matplotlib.pyplot as plt

death_toll = pd.read_csv('covid_avg_deaths.csv')

fig, axes = plt.subplots(nrows=4, ncols=1, figsize=(6,8))

for ax in axes:
    ax.plot(death_toll['Month'], death_toll['New_deaths'],
            color='#af0b1e', alpha=0.1)
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    ax.tick_params(bottom=False, left=False) 
    for location in ['left', 'right', 'top', 'bottom']:
        ax.spines[location].set_visible(False)
        
axes[0].plot(death_toll['Month'][:3], death_toll['New_deaths'][:3],
         color='#af0b1e', linewidth=2.5)
axes[1].plot(death_toll['Month'][2:6], death_toll['New_deaths'][2:6],
         color='#af0b1e', linewidth=2.5)
axes[2].plot(death_toll['Month'][5:10], death_toll['New_deaths'][5:10],
         color='#af0b1e', linewidth=2.5)
axes[3].plot(death_toll['Month'][9:12], death_toll['New_deaths'][9:12],
         color='#af0b1e', linewidth=2.5)

axes[0].text(0.5, -80, '0', alpha=0.5)
axes[0].text(3.5, 2000, '1,844', alpha=0.5)
axes[0].text(11.5, 2400, '2,247', alpha=0.5)

axes[0].text(1.1, -300, 'Jan - Mar', color='#af0b1e',
         weight='bold', rotation=3)
axes[1].text(3.7, 800, 'Mar - Jun', color='#af0b1e', weight='bold')
axes[2].text(7.1, 500, 'Jun - Oct', color='#af0b1e', weight='bold')
axes[3].text(10.5, 600, 'Oct - Dec', color='#af0b1e', weight='bold',
        rotation=45)

#title
axes[0].text(0.5, 3500, 'The virus kills 851 people each day',
         size=14, weight='bold')
axes[0].text(0.5, 3150, 'Average number of daily deaths per month in the US',
         size=12) 

deaths = [2387, 126203, 227178, 295406]
proportions = [round(death/295406, 2) for death in deaths]
xmax_vals = [round(0.5 + proportion * 0.3, 3) for proportion in proportions]
print(proportions)
print(xmax_vals)

#Four bars
for ax, xmax, death in zip(axes, xmax_vals, deaths):
    ax.axhline(y=1600, xmin=0.5, xmax=0.8,
               linewidth=6, color='#af0b1e',
               alpha=0.1)
    ax.axhline(y=1600, xmin=0.5, xmax=xmax,
               linewidth=6, color='#af0b1e')

plt.show()
# Out:
# [0.01, 0.43, 0.77, 1.0]
# [0.503, 0.629, 0.731, 0.8]

# %%
import pandas as pd
import matplotlib.pyplot as plt

death_toll = pd.read_csv('covid_avg_deaths.csv')
deaths = [2387, 126203, 227178, 295406]
proportions = [round(death/295406, 2) for death in deaths]
xmax_vals = [round(0.5 + proportion * 0.3, 3) for proportion in proportions]

fig, axes = plt.subplots(nrows=4, ncols=1, figsize=(6,8))

for ax in axes:
    ax.plot(death_toll['Month'], death_toll['New_deaths'],
            color='#af0b1e', alpha=0.1)
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    ax.tick_params(bottom=False, left=False) 
    for location in ['left', 'right', 'top', 'bottom']:
        ax.spines[location].set_visible(False)
        
axes[0].plot(death_toll['Month'][:3], death_toll['New_deaths'][:3],
         color='#af0b1e', linewidth=2.5)
axes[1].plot(death_toll['Month'][2:6], death_toll['New_deaths'][2:6],
         color='#af0b1e', linewidth=2.5)
axes[2].plot(death_toll['Month'][5:10], death_toll['New_deaths'][5:10],
         color='#af0b1e', linewidth=2.5)
axes[3].plot(death_toll['Month'][9:12], death_toll['New_deaths'][9:12],
         color='#af0b1e', linewidth=2.5)

axes[0].text(0.5, -80, '0', alpha=0.5)
axes[0].text(3.5, 2000, '1,844', alpha=0.5)
axes[0].text(11.5, 2400, '2,247', alpha=0.5)

axes[0].text(1.1, -300, 'Jan - Mar', color='#af0b1e',
         weight='bold', rotation=3)
axes[1].text(3.7, 800, 'Mar - Jun', color='#af0b1e', weight='bold')
axes[2].text(7.1, 500, 'Jun - Oct', color='#af0b1e', weight='bold')
axes[3].text(10.5, 600, 'Oct - Dec', color='#af0b1e', weight='bold',
        rotation=45)

axes[0].text(0.5, 3500, 'The virus kills 851 people each day',
         size=14, weight='bold')
axes[0].text(0.5, 3150, 'Average number of daily deaths per month in the US',
         size=12
            ) 
deaths = [2387, 126203, 227178, 295406]
proportions = [round(death/295406, 2) for death in deaths]
xmax_vals = [round(0.5 + proportion * 0.3, 3) for proportion in proportions]
print(proportions)
print(xmax_vals)

for ax, xmax, death in zip(axes, xmax_vals, deaths):
    ax.axhline(y=1600, xmin=0.5, xmax=0.8,
               linewidth=6, color='#af0b1e',
               alpha=0.1)
    ax.axhline(y=1600, xmin=0.5, xmax=xmax,
               linewidth=6, color='#af0b1e')
    # You'll complete from here
    ax.text(7.5,1850,format(death,','),color='#af0b1e',weight='bold')
    
plt.show()
# Out:
# [0.01, 0.43, 0.77, 1.0]
# [0.503, 0.629, 0.731, 0.8]
